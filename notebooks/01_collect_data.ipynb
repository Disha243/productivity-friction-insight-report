# %%
# 01_collect_data.ipynb
# Productivity Friction Insight Report
# Notebook scaffold for Reddit + App Reviews scraping

# -------------------------------
# Imports
# -------------------------------
import pandas as pd
import numpy as np

# Reddit scraping
import praw

# App reviews scraping
from google_play_scraper import Sort, reviews, app

# -------------------------------
# TODO: Authenticate Reddit
# -------------------------------
# reddit = praw.Reddit(client_id='YOUR_ID', client_secret='YOUR_SECRET', user_agent='YOUR_AGENT')

# -------------------------------
# TODO: Define subreddits to scrape
# -------------------------------
subreddits = ['productivity', 'ADHD', 'Notion']  # Example

# -------------------------------
# TODO: Define apps to scrape reviews
# -------------------------------
apps = ['com.todoist', 'com.notion']  # Google Play package names

# -------------------------------
# TODO: Save raw data to /data folder
# -------------------------------
# Example:
# reddit_posts.to_csv('../data/reddit_posts.csv', index=False)
# app_reviews.to_csv('../data/app_reviews.csv', index=False)

print("Notebook scaffold ready! Add scraping code here.")
# Out:
# Notebook scaffold ready! Add scraping code here.

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\disha\AppData\Local\Programs\Python\Python312\python.exe
